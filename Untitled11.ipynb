# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv(
    '/content/2) Stock Prices Data Set.csv',
    on_bad_lines='skip'
)
df.head()
# Out:
# /tmp/ipython-input-2952039116.py:1: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
#   symbol        date      open     high      low     close      volume
# 0    AAL  2014-01-02   25.0700    25.82    25.06   25.3600   8998943.0
# 1   AAPL  2014-01-02   79.3828  79.5756  78.8601   79.0185  58791957.0
# 2    AAP  2014-01-02  110.3600   111.88   109.29  109.7400    542711.0
# 3   ABBV  2014-01-02   52.1200    52.33    51.52   51.9800   4569061.0
# 4    ABC  2014-01-02   70.1100    70.23    69.48   69.8900   1148391.0

# %%
df = pd.read_csv('/content/2) Stock Prices Data Set.csv', on_bad_lines='skip')
df.head()
# Out:
# /tmp/ipython-input-3860998983.py:1: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/2) Stock Prices Data Set.csv', on_bad_lines='skip')
#   symbol        date      open     high      low     close      volume
# 0    AAL  2014-01-02   25.0700    25.82    25.06   25.3600   8998943.0
# 1   AAPL  2014-01-02   79.3828  79.5756  78.8601   79.0185  58791957.0
# 2    AAP  2014-01-02  110.3600   111.88   109.29  109.7400    542711.0
# 3   ABBV  2014-01-02   52.1200    52.33    51.52   51.9800   4569061.0
# 4    ABC  2014-01-02   70.1100    70.23    69.48   69.8900   1148391.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886910 entries, 0 to 886909
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   symbol  886910 non-null  object
#  1   date    886910 non-null  object
#  2   open    886885 non-null  float64
#  3   high    886888 non-null  object
#  4   low     886886 non-null  object
#  5   close   886899 non-null  float64
#  6   volume  886894 non-null  float64
# dtypes: float64(3), object(4)
# memory usage: 47.4+ MB

# %%
df.columns
# Out:
# Index(['symbol', 'date', 'open', 'high', 'low', 'close', 'volume'], dtype='object')

# %%
df['symbol'].value_counts().head()
# Out:
# symbol
# VNO     1792
# VRSK    1792
# VRSN    1792
# VRTX    1792
# VTR     1792
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.plot(df_stock['close'], color='purple')
plt.title("Stock Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.show()

# %%
df_stock = df[df['symbol'] == 'AAPL']

# %%
df_stock['MA'] = df_stock['close'].rolling(20).mean()
# Out:
# /tmp/ipython-input-3831248018.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stock['MA'] = df_stock['close'].rolling(20).mean()

# %%
plt.figure(figsize=(10,5))
plt.plot(df_stock['close'], label='Close Price', color='olive')
plt.plot(df_stock['MA'], label='Moving Average', color='blue')
plt.legend()
plt.show()

# %% [markdown]
# This time series analysis shows how stock prices change over time.
# The moving average helps smooth short-term fluctuations and highlights the overall trend
